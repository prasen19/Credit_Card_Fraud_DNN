# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, confusion_matrix, f1_score, roc_curve
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, BatchNormalization, Input, Dropout
from tensorflow.keras import Model
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
data = pd.read_csv('creditcard.csv')

data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
data.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df = data.copy()

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Drop Time column as it does not make any sense here.

df.drop(['Time'], axis=1, inplace=True)

# %%
# As amount is having huge range convert it onto log scale which will bring it on small scale.
# 0.001 is added to avoid log(0) problem.

df['Amount'] = np.log(df['Amount'] + 0.001)
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# 0       0.239599  0.098698  0.363787  0.090794  ... -0.018307  0.277838
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.247998  0.771679
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274
# 4       0.592941 -0.270533  0.817739  0.753074  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  0.213454  0.111864
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.214205  0.924384
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.232045  0.578229
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.265245  0.800049
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  5.008105
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724  0.989913
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  5.936641
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  4.816249
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153  4.248367
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731 -0.260067
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527  3.210481
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561  4.217756
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533  2.302685
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  5.379902
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 30 columns]

# %%
x = df.drop(['Class'], axis=1)
y = df['Class']

# %%
x
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V20       V21  \
# 0       0.239599  0.098698  0.363787  0.090794  ...  0.251412 -0.018307
# 1      -0.078803  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775
# 2       0.791461  0.247676 -1.514654  0.207643  ...  0.524980  0.247998
# 3       0.237609  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300
# 4       0.592941 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -4.918215  7.305334  1.914428  4.356170  ...  1.475829  0.213454
# 284803  0.024330  0.294869  0.584800 -0.975926  ...  0.059616  0.214205
# 284804 -0.296827  0.708417  0.432454 -0.484782  ...  0.001396  0.232045
# 284805 -0.686180  0.679145  0.392087 -0.399126  ...  0.127434  0.265245
# 284806  1.577006 -0.414650  0.486180 -0.915427  ...  0.382948  0.261057
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 0       0.277838 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053
# 1      -0.638672  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724
# 2       0.771679  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752
# 3       0.005274 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458
# 4       0.798278 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802  0.111864  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731
# 284803  0.924384  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527
# 284804  0.578229 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561
# 284805  0.800049 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533
# 284806  0.643078  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649
#
#           Amount
# 0       5.008105
# 1       0.989913
# 2       5.936641
# 3       4.816249
# 4       4.248367
# ...          ...
# 284802 -0.260067
# 284803  3.210481
# 284804  4.217756
# 284805  2.302685
# 284806  5.379902
#
# [284807 rows x 29 columns]

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
x = np.array(x)
y = np.array(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %%
# Feature Scaling

scaler = MinMaxScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
# DNN Model

def fraud():
    I = Input(shape=x_train[0].shape)
    
    D1 = Dense(64, activation='elu')(I)
    B1 = BatchNormalization()(D1)
    DR1 = Dropout(0.5)(B1)
    
    D2 = Dense(64, activation='elu')(DR1)
    B2 = BatchNormalization()(D2)
    DR2 = Dropout(0.5)(B2)
    
    D3 = Dense(64, activation='elu')(DR2)
    B3 = BatchNormalization()(D3)
    DR3 = Dropout(0.5)(B3)
    
    out = Dense(1, activation='sigmoid')(DR3)
    
    model = Model(inputs=I, outputs=out)
    
    return model

# %%
model = fraud()
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 29)]              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                1920
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 11,073
# Trainable params: 10,689
# Non-trainable params: 384
# _________________________________________________________________

# %%
model.compile(optmizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['Recall', 'Precision', 'AUC'])

# %%
train = model.fit(x_train, y_train, validation_split=0.1, batch_size=1000, epochs=50)
# Out:
# Train on 192244 samples, validate on 21361 samples
# Epoch 1/50
# 192244/192244 [==============================] - 8s 42us/sample - loss: 0.4495 - Recall: 0.4398 - Precision: 0.0038 - AUC: 0.6011 - val_loss: 0.1092 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.2443
# Epoch 2/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0514 - Recall: 0.3614 - Precision: 0.0860 - AUC: 0.7069 - val_loss: 0.0100 - val_Recall: 0.0750 - val_Precision: 1.0000 - val_AUC: 0.7499
# Epoch 3/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0090 - Recall: 0.5120 - Precision: 0.7203 - AUC: 0.8440 - val_loss: 0.0066 - val_Recall: 0.4750 - val_Precision: 0.8261 - val_AUC: 0.8873
# Epoch 4/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0067 - Recall: 0.5934 - Precision: 0.8277 - AUC: 0.8896 - val_loss: 0.0073 - val_Recall: 0.5750 - val_Precision: 0.8214 - val_AUC: 0.8998
# Epoch 5/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0064 - Recall: 0.5934 - Precision: 0.8208 - AUC: 0.8847 - val_loss: 0.0072 - val_Recall: 0.7000 - val_Precision: 0.8485 - val_AUC: 0.8998
# Epoch 6/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0064 - Recall: 0.5813 - Precision: 0.8283 - AUC: 0.9044 - val_loss: 0.0070 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.8998
# Epoch 7/50
# 192244/192244 [==============================] - 4s 22us/sample - loss: 0.0058 - Recall: 0.5934 - Precision: 0.8174 - AUC: 0.9032 - val_loss: 0.0066 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.8998
# Epoch 8/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0055 - Recall: 0.6265 - Precision: 0.8387 - AUC: 0.9109 - val_loss: 0.0060 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.8998
# Epoch 9/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0053 - Recall: 0.6145 - Precision: 0.8395 - AUC: 0.9230 - val_loss: 0.0061 - val_Recall: 0.7250 - val_Precision: 0.8529 - val_AUC: 0.8998
# Epoch 10/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0056 - Recall: 0.6145 - Precision: 0.8536 - AUC: 0.9153 - val_loss: 0.0059 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9248
# Epoch 11/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0049 - Recall: 0.6446 - Precision: 0.8458 - AUC: 0.9186 - val_loss: 0.0061 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.8998
# Epoch 12/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0049 - Recall: 0.6566 - Precision: 0.8450 - AUC: 0.9218 - val_loss: 0.0052 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9370
# Epoch 13/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0048 - Recall: 0.6596 - Precision: 0.8555 - AUC: 0.9171 - val_loss: 0.0051 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9371
# Epoch 14/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0048 - Recall: 0.6205 - Precision: 0.8512 - AUC: 0.9323 - val_loss: 0.0050 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.9370
# Epoch 15/50
# 192244/192244 [==============================] - 4s 22us/sample - loss: 0.0043 - Recall: 0.6205 - Precision: 0.8477 - AUC: 0.9308 - val_loss: 0.0064 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.8998
# Epoch 16/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0046 - Recall: 0.6928 - Precision: 0.8582 - AUC: 0.9295 - val_loss: 0.0057 - val_Recall: 0.7250 - val_Precision: 0.8529 - val_AUC: 0.9372
# Epoch 17/50
# 192244/192244 [==============================] - 5s 26us/sample - loss: 0.0047 - Recall: 0.6476 - Precision: 0.8600 - AUC: 0.9250 - val_loss: 0.0051 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.9368
# Epoch 18/50
# 192244/192244 [==============================] - 4s 22us/sample - loss: 0.0048 - Recall: 0.6325 - Precision: 0.8502 - AUC: 0.9294 - val_loss: 0.0052 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9370
# Epoch 19/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0044 - Recall: 0.6687 - Precision: 0.8672 - AUC: 0.9341 - val_loss: 0.0053 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9371
# Epoch 20/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0042 - Recall: 0.6867 - Precision: 0.8769 - AUC: 0.9295 - val_loss: 0.0052 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.9366
# Epoch 21/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0045 - Recall: 0.6717 - Precision: 0.8780 - AUC: 0.9266 - val_loss: 0.0058 - val_Recall: 0.7250 - val_Precision: 0.8529 - val_AUC: 0.9372
# Epoch 22/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0042 - Recall: 0.6837 - Precision: 0.8598 - AUC: 0.9312 - val_loss: 0.0054 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9247
# Epoch 23/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0041 - Recall: 0.6807 - Precision: 0.8626 - AUC: 0.9357 - val_loss: 0.0051 - val_Recall: 0.7750 - val_Precision: 0.8378 - val_AUC: 0.9370
# Epoch 24/50
# 192244/192244 [==============================] - 4s 22us/sample - loss: 0.0042 - Recall: 0.6747 - Precision: 0.8615 - AUC: 0.9386 - val_loss: 0.0047 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.9368
# Epoch 25/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0041 - Recall: 0.6988 - Precision: 0.8755 - AUC: 0.9386 - val_loss: 0.0063 - val_Recall: 0.7250 - val_Precision: 0.8529 - val_AUC: 0.8873
# Epoch 26/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0043 - Recall: 0.7229 - Precision: 0.8664 - AUC: 0.9267 - val_loss: 0.0049 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.9370
# Epoch 27/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0042 - Recall: 0.6777 - Precision: 0.8396 - AUC: 0.9326 - val_loss: 0.0055 - val_Recall: 0.7250 - val_Precision: 0.8529 - val_AUC: 0.9372
# Epoch 28/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0042 - Recall: 0.6928 - Precision: 0.8614 - AUC: 0.9342 - val_loss: 0.0049 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9369
# Epoch 29/50
# 192244/192244 [==============================] - 4s 22us/sample - loss: 0.0041 - Recall: 0.7078 - Precision: 0.8608 - AUC: 0.9312 - val_loss: 0.0052 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9247
# Epoch 30/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0040 - Recall: 0.7048 - Precision: 0.8667 - AUC: 0.9356 - val_loss: 0.0051 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9371
# Epoch 31/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0040 - Recall: 0.6958 - Precision: 0.8524 - AUC: 0.9342 - val_loss: 0.0050 - val_Recall: 0.7750 - val_Precision: 0.8378 - val_AUC: 0.9364
# Epoch 32/50
# 192244/192244 [==============================] - 4s 22us/sample - loss: 0.0039 - Recall: 0.6867 - Precision: 0.8413 - AUC: 0.9326 - val_loss: 0.0047 - val_Recall: 0.7750 - val_Precision: 0.8611 - val_AUC: 0.9368
# Epoch 33/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0038 - Recall: 0.6898 - Precision: 0.8577 - AUC: 0.9402 - val_loss: 0.0053 - val_Recall: 0.7250 - val_Precision: 0.8529 - val_AUC: 0.9371
# Epoch 34/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0041 - Recall: 0.6898 - Precision: 0.8450 - AUC: 0.9266 - val_loss: 0.0051 - val_Recall: 0.7000 - val_Precision: 0.8485 - val_AUC: 0.9247
# Epoch 35/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0040 - Recall: 0.7139 - Precision: 0.8618 - AUC: 0.9312 - val_loss: 0.0054 - val_Recall: 0.7500 - val_Precision: 0.8108 - val_AUC: 0.9354
# Epoch 36/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0039 - Recall: 0.6958 - Precision: 0.8717 - AUC: 0.9327 - val_loss: 0.0056 - val_Recall: 0.7750 - val_Precision: 0.8158 - val_AUC: 0.9356
# Epoch 37/50
# 192244/192244 [==============================] - 4s 19us/sample - loss: 0.0043 - Recall: 0.6958 - Precision: 0.8556 - AUC: 0.9266 - val_loss: 0.0048 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9245
# Epoch 38/50
# 192244/192244 [==============================] - 4s 19us/sample - loss: 0.0041 - Recall: 0.6928 - Precision: 0.8647 - AUC: 0.9220 - val_loss: 0.0061 - val_Recall: 0.7000 - val_Precision: 0.8485 - val_AUC: 0.9123
# Epoch 39/50
# 192244/192244 [==============================] - 4s 20us/sample - loss: 0.0036 - Recall: 0.7319 - Precision: 0.8587 - AUC: 0.9342 - val_loss: 0.0060 - val_Recall: 0.7000 - val_Precision: 0.8485 - val_AUC: 0.8998
# Epoch 40/50
# 192244/192244 [==============================] - 4s 20us/sample - loss: 0.0041 - Recall: 0.6717 - Precision: 0.8447 - AUC: 0.9297 - val_loss: 0.0049 - val_Recall: 0.7500 - val_Precision: 0.8333 - val_AUC: 0.9368
# Epoch 41/50
# 192244/192244 [==============================] - 4s 20us/sample - loss: 0.0040 - Recall: 0.6958 - Precision: 0.8652 - AUC: 0.9281 - val_loss: 0.0052 - val_Recall: 0.7250 - val_Precision: 0.8529 - val_AUC: 0.9246
# Epoch 42/50
# 192244/192244 [==============================] - 4s 20us/sample - loss: 0.0040 - Recall: 0.7169 - Precision: 0.8592 - AUC: 0.9297 - val_loss: 0.0049 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9245
# Epoch 43/50
# 192244/192244 [==============================] - 4s 20us/sample - loss: 0.0041 - Recall: 0.7169 - Precision: 0.8686 - AUC: 0.9221 - val_loss: 0.0049 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9245
# Epoch 44/50
# 192244/192244 [==============================] - 4s 20us/sample - loss: 0.0037 - Recall: 0.7349 - Precision: 0.8683 - AUC: 0.9343 - val_loss: 0.0049 - val_Recall: 0.7500 - val_Precision: 0.8333 - val_AUC: 0.9362
# Epoch 45/50
# 192244/192244 [==============================] - 4s 19us/sample - loss: 0.0038 - Recall: 0.7018 - Precision: 0.8694 - AUC: 0.9342 - val_loss: 0.0055 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9122
# Epoch 46/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0038 - Recall: 0.7349 - Precision: 0.8592 - AUC: 0.9373 - val_loss: 0.0049 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9245
# Epoch 47/50
# 192244/192244 [==============================] - 4s 20us/sample - loss: 0.0039 - Recall: 0.7108 - Precision: 0.8582 - AUC: 0.9298 - val_loss: 0.0057 - val_Recall: 0.7250 - val_Precision: 0.8529 - val_AUC: 0.9123
# Epoch 48/50
# 192244/192244 [==============================] - 4s 21us/sample - loss: 0.0040 - Recall: 0.7199 - Precision: 0.8691 - AUC: 0.9328 - val_loss: 0.0051 - val_Recall: 0.7500 - val_Precision: 0.8571 - val_AUC: 0.9121
# Epoch 49/50
# 192244/192244 [==============================] - 4s 22us/sample - loss: 0.0041 - Recall: 0.7199 - Precision: 0.8691 - AUC: 0.9296 - val_loss: 0.0069 - val_Recall: 0.6750 - val_Precision: 0.8438 - val_AUC: 0.8873
# Epoch 50/50
# 192244/192244 [==============================] - 4s 20us/sample - loss: 0.0040 - Recall: 0.7169 - Precision: 0.8623 - AUC: 0.9252 - val_loss: 0.0047 - val_Recall: 0.7750 - val_Precision: 0.8378 - val_AUC: 0.9242

# %%
results = model.evaluate(x_test, y_test, batch_size=1000)
# Out:
# 71202/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print('Loss: ' + str(results[0]))
print('Recall: ' + str(results[1]))
print('Precision: ' + str(results[2]))
print('AUC: ' + str(results[3]))
# Out:
# Loss: 0.0042387684306020934
# Recall: 0.81666666
# Precision: 0.7903226
# AUC: 0.9360491

# %%
pred = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, pred > 0.5)
plt.figure()
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion matrix')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 15.0, 'Predicted label')

# %%
fpr, tpr, _ = roc_curve(y_test, pred)
plt.figure()
plt.plot(fpr, tpr)
plt.xlabel('False positives')
plt.ylabel('True positives')
plt.title('ROC Curve')
# Out:
# Text(0.5, 1.0, 'ROC Curve')

# %%
# Plots to display loss and accuracy

plt.figure()
plt.plot(train.history['Recall'])
plt.plot(train.history['val_Recall'])
plt.title('Model Recall')
plt.ylabel('Recall')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

plt.figure()
plt.plot(train.history['loss'])
plt.plot(train.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.ylim([0,0.02])
plt.show()
